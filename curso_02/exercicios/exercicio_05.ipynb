# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

data_url = "http://lib.stat.cmu.edu/datasets/boston"
raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
X = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
y = raw_df.values[1::2, 2]


train, test = train_test_split(raw_df, test_size = 0.20, random_state=0)
# print("apresentar resultado train")
# print(train)
#print(type(train))

# z_scaler = StandardScaler()
# data_z_scaled = z_scaler.fit_transform(train)

# #print(data_z_scaled)

pca = PCA(n_components=2)
data_z_scaled_pca = pca.fit_transform(train.dropna())

#print(data_z_scaled_pca)

dados1 = pd.DataFrame(
    {
    'PCA1':data_z_scaled_pca[:,0],
    'PCA2': data_z_scaled_pca[:,1]
    }
)
sns.scatterplot(x='PCA1', y='PCA2', data=dados1)
plt.show()

print(data_z_scaled_pca)
# Out:
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# <>:9: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\ivanmds\AppData\Local\Temp\ipykernel_25388\2431997574.py:9: SyntaxWarning: invalid escape sequence '\s'
#   raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
# [[-1.06754167e+01 -8.12857852e+00]
#  [-2.14277375e+02  5.21413271e+01]
#  [-9.72874375e+01  3.13605767e+01]
#  [ 3.31173586e+01  2.79931035e+01]
#  [-1.11997843e+02  3.18011041e+00]
#  [-1.01225105e+02  2.47743492e+01]
#  [-1.84269283e+02  3.82672648e+00]
#  [ 2.60839826e+02 -3.03535572e-01]
#  [ 2.60215749e+02 -5.77583462e+00]
#  [-1.14392709e+01 -1.43463623e+01]
#  [-1.05997824e+01 -7.51692366e+00]
#  [-9.63146116e+01  4.01635739e+01]
#  [-1.84330490e+02  3.31050626e+00]
#  [-9.81607020e+01  2.42355294e+01]
#  [-5.88095358e-01  3.16936750e+01]
#  [-5.63134419e+01 -6.95621320e+01]
#  [ 2.61859385e+02  5.91821736e+00]
#  [-9.40920703e+01  2.22825615e+01]
#  [-9.99798557e+01  3.49287298e+01]
# ...

# %% [markdown]
# resposta d
